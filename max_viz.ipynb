# %%
import pickle

import mediapy


with open("sim_state_frames.pkl", "rb") as f:
    sim_state_frames = pickle.load(f)

mediapy.show_videos(sim_state_frames, fps=15, codec='gif')
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>0</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>1</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
# ...
